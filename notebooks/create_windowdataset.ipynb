# %% [markdown]
# # Create window datasets (balanced)

# %%
import os
import re
import numpy as np
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler

# define data root
# this is the path to the ROAMM folder on local machine
data_root = r"/gpfs1/pi/djangraw/mindless_reading/data"
random_seed = 42
# define window size and sampling rate
sfreq = 256
window_seconds = 5
window_size = int(sfreq * window_seconds)

all_subjects = sorted([d for d in os.listdir(data_root) if d.startswith('s') and os.path.isdir(os.path.join(data_root, d))])

min_sub_num = 0

for subject_id in all_subjects:
    df = pd.DataFrame()
    m = re.match(r"^s(\d+)$", subject_id)
    sub_num = int(m.group(1))
    if sub_num <= min_sub_num:
        print(f"Subject {subject_id} is skipped")
        continue

    subject_dir = os.path.join(data_root, subject_id, "ml_data")
    save_dir = os.path.join(subject_dir, f'{window_size}window_datasets')

    pkl_files = [f for f in os.listdir(subject_dir) if f.endswith('.pkl')]
    # make sure each subject has 5 runs of data
    if len(pkl_files) != 5:
        raise ValueError(f"Subject {subject_id} has {len(pkl_files)} runs instead of 5")
    
    for pkl_file in pkl_files:
        df_sub_single_run = pd.read_pickle(os.path.join(subject_dir, pkl_file))
        df_sub_single_run = df_sub_single_run[df_sub_single_run['first_pass_reading'] == 1]
        # convert bool col explicitly to avoid pandas warning
        for col in ['is_blink', 'is_sacc', 'is_fix', 'is_mw', 'first_pass_reading']:
            df_sub_single_run[col] = df_sub_single_run[col] == True

        # filter out samples 2 seconds before page end
        mask = df_sub_single_run['time'] < df_sub_single_run['page_end']-2
        df_sub_single_run = df_sub_single_run[mask]
        # append to the dataframe
        df = pd.concat([df, df_sub_single_run])
        # add subject id to the dataframe
        df['subject_id'] = subject_id
    print(f'Subject {subject_id} has been loaded.')
    
    # normalize pupil size features
    df['blink_interp_LPupil_norm'] = df['blink_interp_LPupil'] / df['blink_interp_LPupil'].median()
    df['blink_interp_RPupil_norm'] = df['blink_interp_RPupil'] / df['blink_interp_RPupil'].median()

    windowed_data = []
    windowed_labels = []

    # Process data in chunks of window_size
    for i in range(0, len(df), window_size):
        window = df.iloc[i:i+window_size]
        # Skip if window is too small
        if len(window) < window_size:
            continue
        # Check if labels are consistent in this window
        labels_in_window = window['is_mw'].unique()
        if len(labels_in_window) > 1:
            # Skip windows with mixed labels
            continue

        # Extract features for this window: keep as 2D array (window_size x feature_number)
        windowed_data.append(window.values)
        # Use the consistent label
        windowed_labels.append(labels_in_window[0])

    # check class distribution before undersampling
    unique, _ = np.unique(windowed_labels, return_counts=True)
    if len(unique) < 2:
        print(f"Subject {subject_id} has only one class in windowed labels. Skipping undersampling.")
        continue

    # Use RandomUnderSampler on flattened data, then recover 3D structure
    windowed_data_flat = [w.flatten() for w in windowed_data]
    undersampler = RandomUnderSampler(random_state=random_seed)
    X_resampled_flat, y_resampled = undersampler.fit_resample(windowed_data_flat, windowed_labels)
    # Recover 3D array: (n_samples, window_size, n_features)
    window_size = windowed_data[0].shape[0]
    n_features = windowed_data[0].shape[1]
    X_resampled = np.array(X_resampled_flat).reshape(-1, window_size, n_features)
    X = np.transpose(X_resampled, (0, 2, 1))  # (N, num_channels, window_size)
    y = np.array(y_resampled, dtype=int)

    # get col names
    col_names = df.columns.tolist()

    # save windowed data and labels
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    np.save(os.path.join(save_dir, f'{subject_id}_{window_size}windowed_data.npy'), X)
    np.save(os.path.join(save_dir, f'{subject_id}_{window_size}windowed_labels.npy'), y)

    # for col names, only save one copy
    file_path = os.path.join(save_dir, f'{subject_id}_col_names.npy')
    # if not os.path.exists(file_path):
    np.save(file_path, col_names)
    
    print(f'Windowed data and labels for subject {subject_id} have been saved.')
# Out:
# Subject s10014 has been loaded.
# Windowed data and labels for subject s10014 have been saved.
# Subject s10052 has been loaded.
# Windowed data and labels for subject s10052 have been saved.
# Subject s10059 has been loaded.
# Windowed data and labels for subject s10059 have been saved.
# Subject s10073 has been loaded.
# Windowed data and labels for subject s10073 have been saved.
# Subject s10081 has been loaded.
# Windowed data and labels for subject s10081 have been saved.
# Subject s10084 has been loaded.
# Windowed data and labels for subject s10084 have been saved.
# Subject s10085 has been loaded.
# Windowed data and labels for subject s10085 have been saved.
# Subject s10089 has been loaded.
# Windowed data and labels for subject s10089 have been saved.
# Subject s10094 has been loaded.
# Windowed data and labels for subject s10094 have been saved.
# Subject s10100 has been loaded.
# Windowed data and labels for subject s10100 have been saved.
# Subject s10103 has been loaded.
# Subject s10103 has only one class in windowed labels. Skipping undersampling.
# Subject s10110 has been loaded.
# Subject s10110 has only one class in windowed labels. Skipping undersampling.
# Subject s10111 has been loaded.
# Windowed data and labels for subject s10111 have been saved.
# Subject s10115 has been loaded.
# Windowed data and labels for subject s10115 have been saved.
# Subject s10117 has been loaded.
# Windowed data and labels for subject s10117 have been saved.
# Subject s10121 has been loaded.
# Windowed data and labels for subject s10121 have been saved.
# Subject s10125 has been loaded.
# Windowed data and labels for subject s10125 have been saved.
# Subject s10138 has been loaded.
# Windowed data and labels for subject s10138 have been saved.
# Subject s10139 has been loaded.
# Windowed data and labels for subject s10139 have been saved.
# Subject s10141 has been loaded.
# Windowed data and labels for subject s10141 have been saved.
# Subject s10144 has been loaded.
# Windowed data and labels for subject s10144 have been saved.
# Subject s10145 has been loaded.
# Windowed data and labels for subject s10145 have been saved.
# Subject s10148 has been loaded.
# Windowed data and labels for subject s10148 have been saved.
# Subject s10153 has been loaded.
# Windowed data and labels for subject s10153 have been saved.
# Subject s10156 has been loaded.
# Windowed data and labels for subject s10156 have been saved.
# Subject s10158 has been loaded.
# Windowed data and labels for subject s10158 have been saved.
# Subject s10159 has been loaded.
# Windowed data and labels for subject s10159 have been saved.
# Subject s10160 has been loaded.
# Windowed data and labels for subject s10160 have been saved.
# Subject s10165 has been loaded.
# Windowed data and labels for subject s10165 have been saved.
# Subject s10173 has been loaded.
# Windowed data and labels for subject s10173 have been saved.
# Subject s10177 has been loaded.
# Windowed data and labels for subject s10177 have been saved.
# Subject s10178 has been loaded.
# Windowed data and labels for subject s10178 have been saved.
# Subject s10180 has been loaded.
# Windowed data and labels for subject s10180 have been saved.
# Subject s10181 has been loaded.
# Windowed data and labels for subject s10181 have been saved.
# Subject s10183 has been loaded.
# Windowed data and labels for subject s10183 have been saved.
# Subject s10185 has been loaded.
# Subject s10185 has only one class in windowed labels. Skipping undersampling.
# Subject s10186 has been loaded.
# Windowed data and labels for subject s10186 have been saved.
# Subject s10188 has been loaded.
# Windowed data and labels for subject s10188 have been saved.
# Subject s10192 has been loaded.
# Windowed data and labels for subject s10192 have been saved.
# Subject s10195 has been loaded.
# Windowed data and labels for subject s10195 have been saved.
# Subject s10196 has been loaded.
# Windowed data and labels for subject s10196 have been saved.
# Subject s10197 has been loaded.
# Windowed data and labels for subject s10197 have been saved.
# Subject s10200 has been loaded.
# Windowed data and labels for subject s10200 have been saved.
# Subject s10202 has been loaded.
# Windowed data and labels for subject s10202 have been saved.

# %% [markdown]
# # Create window datasets (imbalanced)

# %%
import os
import re
import numpy as np
import pandas as pd

# define data root
# this is the path to the ROAMM folder on local machine
data_root = r"/gpfs1/pi/djangraw/mindless_reading/data"
# define window size and sampling rate
sfreq = 256
window_seconds = 2
window_size = int(sfreq * window_seconds)
# define boolean variable to overwrite column names
over_col_names = False
# set this to the last subject that has been processed, so that we can resume from the next subject in the next run
min_sub_num = 0

# get all subjects in the data root
all_subjects = sorted([d for d in os.listdir(data_root) if d.startswith('s') and os.path.isdir(os.path.join(data_root, d))])
for subject_id in all_subjects:
    df = pd.DataFrame()
    m = re.match(r"^s(\d+)$", subject_id)
    sub_num = int(m.group(1))
    if sub_num <= min_sub_num:
        print(f"Subject {subject_id} is skipped")
        continue

    subject_dir = os.path.join(data_root, subject_id, "ml_data")
    save_dir = os.path.join(subject_dir, f'{window_size}window_datasets')

    pkl_files = [f for f in os.listdir(subject_dir) if f.endswith('.pkl')]
    # make sure each subject has 5 runs of data
    if len(pkl_files) != 5:
        raise ValueError(f"Subject {subject_id} has {len(pkl_files)} runs instead of 5")
    
    for pkl_file in pkl_files:
        df_sub_single_run = pd.read_pickle(os.path.join(subject_dir, pkl_file))
        df_sub_single_run = df_sub_single_run[df_sub_single_run['first_pass_reading'] == 1]
        # convert bool col explicitly to avoid pandas warning
        for col in ['is_blink', 'is_sacc', 'is_fix', 'is_mw', 'first_pass_reading']:
            df_sub_single_run[col] = df_sub_single_run[col] == True

        # filter out samples 2 seconds before page end
        mask = df_sub_single_run['time'] < df_sub_single_run['page_end']-2
        df_sub_single_run = df_sub_single_run[mask]
        # append to the dataframe
        df = pd.concat([df, df_sub_single_run])
        # add subject id to the dataframe
        df['subject_id'] = subject_id
    print(f'Subject {subject_id} has been loaded.')
    
    # normalize pupil size features
    df['blink_interp_LPupil_norm'] = df['blink_interp_LPupil'] / df['blink_interp_LPupil'].median()
    df['blink_interp_RPupil_norm'] = df['blink_interp_RPupil'] / df['blink_interp_RPupil'].median()

    windowed_data = []
    windowed_labels = []

    # Process data in chunks of window_size
    for i in range(0, len(df), window_size):
        window = df.iloc[i:i+window_size]
        # Skip if window is too small
        if len(window) < window_size:
            continue
        # Check if labels are consistent in this window
        labels_in_window = window['is_mw'].unique()
        if len(labels_in_window) > 1:
            # Skip windows with mixed labels
            continue

        # Extract features for this window: keep as 2D array (window_size x feature_number)
        windowed_data.append(window.values)
        # Use the consistent label
        windowed_labels.append(labels_in_window[0])

    # save windowed data and labels
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    # transpose data to (N, num_channels, window_size)
    X = np.transpose(np.array(windowed_data), (0, 2, 1))  # (N, num_channels, window_size)
    np.save(os.path.join(save_dir, f'{subject_id}_{window_size}windowed_data_imbalanced.npy'), X)
    np.save(os.path.join(save_dir, f'{subject_id}_{window_size}windowed_labels_imbalanced.npy'), np.array(windowed_labels, dtype=int))

    # for col names, only save one copy
    file_path = os.path.join(save_dir, f'{subject_id}_col_names.npy')
    if not os.path.exists(file_path) or over_col_names:
        np.save(file_path, df.columns.tolist())
    
    print(f'Windowed data and labels for subject {subject_id} have been saved.')
# Out:
# Subject s10014 has been loaded.
# Windowed data and labels for subject s10014 have been saved.
# Subject s10052 has been loaded.
# Windowed data and labels for subject s10052 have been saved.
# Subject s10059 has been loaded.
# Windowed data and labels for subject s10059 have been saved.
# Subject s10073 has been loaded.
# Windowed data and labels for subject s10073 have been saved.
# Subject s10081 has been loaded.
# Windowed data and labels for subject s10081 have been saved.
# Subject s10084 has been loaded.
# Windowed data and labels for subject s10084 have been saved.
# Subject s10085 has been loaded.
# Windowed data and labels for subject s10085 have been saved.
# Subject s10089 has been loaded.
# Windowed data and labels for subject s10089 have been saved.
# Subject s10094 has been loaded.
# Windowed data and labels for subject s10094 have been saved.
# Subject s10100 has been loaded.
# Windowed data and labels for subject s10100 have been saved.
# Subject s10103 has been loaded.
# Windowed data and labels for subject s10103 have been saved.
# Subject s10110 has been loaded.
# Windowed data and labels for subject s10110 have been saved.
# Subject s10111 has been loaded.
# Windowed data and labels for subject s10111 have been saved.
# Subject s10115 has been loaded.
# Windowed data and labels for subject s10115 have been saved.
# Subject s10117 has been loaded.
# Windowed data and labels for subject s10117 have been saved.
# Subject s10121 has been loaded.
# Windowed data and labels for subject s10121 have been saved.
# Subject s10125 has been loaded.
# Windowed data and labels for subject s10125 have been saved.
# Subject s10138 has been loaded.
# Windowed data and labels for subject s10138 have been saved.
# Subject s10139 has been loaded.
# Windowed data and labels for subject s10139 have been saved.
# Subject s10141 has been loaded.
# Windowed data and labels for subject s10141 have been saved.
# Subject s10144 has been loaded.
# Windowed data and labels for subject s10144 have been saved.
# Subject s10145 has been loaded.
# Windowed data and labels for subject s10145 have been saved.
# Subject s10148 has been loaded.
# Windowed data and labels for subject s10148 have been saved.
# Subject s10153 has been loaded.
# Windowed data and labels for subject s10153 have been saved.
# Subject s10156 has been loaded.
# Windowed data and labels for subject s10156 have been saved.
# Subject s10158 has been loaded.
# Windowed data and labels for subject s10158 have been saved.
# Subject s10159 has been loaded.
# Windowed data and labels for subject s10159 have been saved.
# Subject s10160 has been loaded.
# Windowed data and labels for subject s10160 have been saved.
# Subject s10165 has been loaded.
# Windowed data and labels for subject s10165 have been saved.
# Subject s10173 has been loaded.
# Windowed data and labels for subject s10173 have been saved.
# Subject s10177 has been loaded.
# Windowed data and labels for subject s10177 have been saved.
# Subject s10178 has been loaded.
# Windowed data and labels for subject s10178 have been saved.
# Subject s10180 has been loaded.
# Windowed data and labels for subject s10180 have been saved.
# Subject s10181 has been loaded.
# Windowed data and labels for subject s10181 have been saved.
# Subject s10183 has been loaded.
# Windowed data and labels for subject s10183 have been saved.
# Subject s10185 has been loaded.
# Windowed data and labels for subject s10185 have been saved.
# Subject s10186 has been loaded.
# Windowed data and labels for subject s10186 have been saved.
# Subject s10188 has been loaded.
# Windowed data and labels for subject s10188 have been saved.
# Subject s10192 has been loaded.
# Windowed data and labels for subject s10192 have been saved.
# Subject s10195 has been loaded.
# Windowed data and labels for subject s10195 have been saved.
# Subject s10196 has been loaded.
# Windowed data and labels for subject s10196 have been saved.
# Subject s10197 has been loaded.
# Windowed data and labels for subject s10197 have been saved.
# Subject s10200 has been loaded.
# Windowed data and labels for subject s10200 have been saved.
# Subject s10202 has been loaded.
# Windowed data and labels for subject s10202 have been saved.

# %% [markdown]
# # QA on datasets

# %% [markdown]
# ## Comparison between balanced and imbalanced datasets

# %%
import os
import re
import numpy as np
import pandas as pd

# define data root
# this is the path to the ROAMM folder on local machine
data_root = r"/gpfs1/pi/djangraw/mindless_reading/data"
# define window size and sampling rate
sfreq = 256
window_seconds = 5
window_size = int(sfreq * window_seconds)
subject_id = "s10014"
save_dir = os.path.join(data_root, subject_id, "ml_data", f'{window_size}window_datasets')

balanced = np.load(os.path.join(save_dir, f'{subject_id}_{window_size}windowed_data.npy'))
imbalanced = np.load(os.path.join(save_dir, f'{subject_id}_{window_size}windowed_data_imbalanced.npy'), allow_pickle=True)

# %% [markdown]
# ## Sample size for imbalanced dataset

# %%
import os
import re
import numpy as np
import pandas as pd

# define data root
# this is the path to the ROAMM folder on local machine
data_root = r"/gpfs1/pi/djangraw/mindless_reading/data"
# define window size and sampling rate
sfreq = 256
window_seconds = 2
window_size = int(sfreq * window_seconds)

# get all subjects in the data root
all_subjects = sorted([d for d in os.listdir(data_root) if d.startswith('s') and os.path.isdir(os.path.join(data_root, d))])
for subject_id in all_subjects:
    dir = os.path.join(data_root, subject_id, "ml_data", f'{window_size}window_datasets')

    labels = np.load(os.path.join(dir, f'{subject_id}_{window_size}windowed_labels_imbalanced.npy'))
    print(f'Subject {subject_id}: MW = {sum(labels)}, Non-MW = {len(labels) - sum(labels)}')
# Out:
# Subject s10014: MW = 130, Non-MW = 604
# Subject s10052: MW = 119, Non-MW = 820
# Subject s10059: MW = 26, Non-MW = 1273
# Subject s10073: MW = 70, Non-MW = 1102
# Subject s10081: MW = 35, Non-MW = 666
# Subject s10084: MW = 31, Non-MW = 798
# Subject s10085: MW = 35, Non-MW = 921
# Subject s10089: MW = 24, Non-MW = 1200
# Subject s10094: MW = 7, Non-MW = 1258
# Subject s10100: MW = 67, Non-MW = 638
# Subject s10103: MW = 3, Non-MW = 1078
# Subject s10110: MW = 9, Non-MW = 1196
# Subject s10111: MW = 57, Non-MW = 609
# Subject s10115: MW = 87, Non-MW = 932
# Subject s10117: MW = 184, Non-MW = 1064
# Subject s10121: MW = 80, Non-MW = 1502
# Subject s10125: MW = 232, Non-MW = 1391
# Subject s10138: MW = 69, Non-MW = 545
# Subject s10139: MW = 81, Non-MW = 1218
# Subject s10141: MW = 37, Non-MW = 984
# Subject s10144: MW = 18, Non-MW = 1660
# Subject s10145: MW = 22, Non-MW = 508
# Subject s10148: MW = 42, Non-MW = 1207
# Subject s10153: MW = 130, Non-MW = 811
# Subject s10156: MW = 95, Non-MW = 894
# Subject s10158: MW = 100, Non-MW = 903
# Subject s10159: MW = 48, Non-MW = 631
# Subject s10160: MW = 33, Non-MW = 1125
# Subject s10165: MW = 91, Non-MW = 682
# Subject s10173: MW = 14, Non-MW = 1058
# Subject s10177: MW = 30, Non-MW = 975
# Subject s10178: MW = 32, Non-MW = 1461
# Subject s10180: MW = 220, Non-MW = 695
# Subject s10181: MW = 42, Non-MW = 415
# Subject s10183: MW = 128, Non-MW = 2021
# Subject s10185: MW = 1, Non-MW = 1503
# Subject s10186: MW = 45, Non-MW = 1383
# Subject s10188: MW = 28, Non-MW = 1328
# Subject s10192: MW = 180, Non-MW = 1106
# Subject s10195: MW = 58, Non-MW = 678
# Subject s10196: MW = 5, Non-MW = 1310
# Subject s10197: MW = 6, Non-MW = 1217
# Subject s10200: MW = 33, Non-MW = 1093
# Subject s10202: MW = 18, Non-MW = 824
